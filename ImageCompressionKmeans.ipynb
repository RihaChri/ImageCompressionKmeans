# %% [markdown]
# <a href="https://colab.research.google.com/github/RihaChri/ImageCompressionKmeans/blob/main/ImageCompressionKmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.image as img 
import sys
# from scipy.io import loadmat 
from scipy import misc 
import imageio

def read_image(): 
	# loading as 3d matrix 
	img = imageio.imread('/content/drive/MyDrive/Colab Notebooks/ImageCompressionKmeans/Kroko.jpg') 
	img = img / 255
	return img 

def initialize_means(img, clusters): 
	
	# reshaping it or flattening it into a 2d matrix 
	points = np.reshape(img, (img.shape[0] * img.shape[1], 
											img.shape[2]))
	m, n = points.shape 
  
	# means is the array of assumed means or centroids. 
	means = np.zeros((clusters, n)) 

	# random initialization of means. 
	for i in range(clusters): 
		rand1 = int(np.random.random(1)*10) 
		rand2 = int(np.random.random(1)*8) 
		means[i, 0] = points[rand1, 0] 
		means[i, 1] = points[rand2, 1]
		means[i, 2] = points[rand2, 2]
	#print(means)
	return points, means 


# Function to measure the euclidean 
def distance(x1, y1, x2, y2): 
	dist = np.square(x1 - x2) + np.square(y1 - y2) 
	dist = np.sqrt(dist) 
	return dist 


def k_means(points, means, clusters): 
	iterations = 10 # the number of iterations 
	m, n = points.shape 
	# these are the index values that 
	# correspond to the cluster to 
	# which each pixel belongs to. 
	index = np.zeros(m) 

	# k-means algorithm. 
	while(iterations > 0): 
		for j in range(len(points)): 
			if 100*j/len(points) % 5 < 10/len(points): print('Current Iteration ',iterations,' is at ',100*j/len(points),'%')
   
			# initialize minimum value to a large value 
			minv = 1000
			temp = None
			
			for k in range(clusters): 
				
				x1 = points[j, 0] 
				y1 = points[j, 1] 
				x2 = means[k, 0] 
				y2 = means[k, 1] 
				
				if(distance(x1, y1, x2, y2) < minv):		 
					minv = distance(x1, y1, x2, y2) 
					temp = k 
					index[j] = k 
		
		for k in range(clusters): 
			
			sumx = 0
			sumy = 0
			count = 0
			
			for j in range(len(points)): 
				
				if(index[j] == k): 
					sumx += points[j, 0] 
					sumy += points[j, 1] 
					count += 1
			
			if(count == 0): 
				count = 1	
			
			means[k, 0] = float(sumx / count) 
			means[k, 1] = float(sumy / count)	 
			
		iterations -= 1

	return means, index 


def compress_image(means, index, img): 

	# recovering the compressed image by 
	# assigning each pixel to its corresponding centroid. 
	centroid = np.array(means) 
	recovered = centroid[index.astype(int), :] 
	
	# getting back the 3d matrix (row, col, rgb(3)) 
	recovered = np.reshape(recovered, (img.shape[0], img.shape[1], 
													img.shape[2])) 

	# plotting the compressed image. 
	plt.imshow(recovered) 
	plt.show() 

	# saving the compressed image. 
#	misc.imsave('compressed_' + str(clusters) +
#						'_colors.png', recovered) 



img = read_image() 

clusters = 16 

points, means = initialize_means(img, clusters) 
means, index = k_means(points, means, clusters) 
compress_image(means, index, img)
# Out:
# Current Iteration  10  is at  0.0 %
# Current Iteration  10  is at  5.0 %
# Current Iteration  10  is at  10.0 %
# Current Iteration  10  is at  15.0 %
# Current Iteration  10  is at  20.0 %
# Current Iteration  10  is at  25.0 %
# Current Iteration  10  is at  30.0 %
# Current Iteration  10  is at  35.0 %
# Current Iteration  10  is at  40.0 %
# Current Iteration  10  is at  45.0 %
# Current Iteration  10  is at  50.0 %
# Current Iteration  10  is at  55.0 %
# Current Iteration  10  is at  60.0 %
# Current Iteration  10  is at  65.0 %
# Current Iteration  10  is at  70.0 %
# Current Iteration  10  is at  75.0 %
# Current Iteration  10  is at  80.0 %
# Current Iteration  10  is at  85.0 %
# Current Iteration  10  is at  90.0 %
# Current Iteration  10  is at  95.0 %
# Current Iteration  9  is at  0.0 %
# Current Iteration  9  is at  5.0 %
# Current Iteration  9  is at  10.0 %
# Current Iteration  9  is at  15.0 %
# Current Iteration  9  is at  20.0 %
# Current Iteration  9  is at  25.0 %
# Current Iteration  9  is at  30.0 %
# Current Iteration  9  is at  35.0 %
# Current Iteration  9  is at  40.0 %
# Current Iteration  9  is at  45.0 %
# Current Iteration  9  is at  50.0 %
# Current Iteration  9  is at  55.0 %
# Current Iteration  9  is at  60.0 %
# Current Iteration  9  is at  65.0 %
# Current Iteration  9  is at  70.0 %
# Current Iteration  9  is at  75.0 %
# Current Iteration  9  is at  80.0 %
# Current Iteration  9  is at  85.0 %
# Current Iteration  9  is at  90.0 %
# Current Iteration  9  is at  95.0 %
# Current Iteration  8  is at  0.0 %
# Current Iteration  8  is at  5.0 %
# Current Iteration  8  is at  10.0 %
# Current Iteration  8  is at  15.0 %
# Current Iteration  8  is at  20.0 %
# Current Iteration  8  is at  25.0 %
# Current Iteration  8  is at  30.0 %
# Current Iteration  8  is at  35.0 %
# Current Iteration  8  is at  40.0 %
# Current Iteration  8  is at  45.0 %
# Current Iteration  8  is at  50.0 %
# Current Iteration  8  is at  55.0 %
# Current Iteration  8  is at  60.0 %
# Current Iteration  8  is at  65.0 %
# Current Iteration  8  is at  70.0 %
# Current Iteration  8  is at  75.0 %
# Current Iteration  8  is at  80.0 %
# Current Iteration  8  is at  85.0 %
# Current Iteration  8  is at  90.0 %
# Current Iteration  8  is at  95.0 %
# Current Iteration  7  is at  0.0 %
# Current Iteration  7  is at  5.0 %
# Current Iteration  7  is at  10.0 %
# Current Iteration  7  is at  15.0 %
# Current Iteration  7  is at  20.0 %
# Current Iteration  7  is at  25.0 %
# Current Iteration  7  is at  30.0 %
# Current Iteration  7  is at  35.0 %
# Current Iteration  7  is at  40.0 %
# Current Iteration  7  is at  45.0 %
# Current Iteration  7  is at  50.0 %
# Current Iteration  7  is at  55.0 %
# Current Iteration  7  is at  60.0 %
# Current Iteration  7  is at  65.0 %
# Current Iteration  7  is at  70.0 %
# Current Iteration  7  is at  75.0 %
# Current Iteration  7  is at  80.0 %
# Current Iteration  7  is at  85.0 %
# Current Iteration  7  is at  90.0 %
# Current Iteration  7  is at  95.0 %
# Current Iteration  6  is at  0.0 %
# Current Iteration  6  is at  5.0 %
# Current Iteration  6  is at  10.0 %
# Current Iteration  6  is at  15.0 %
# Current Iteration  6  is at  20.0 %
# Current Iteration  6  is at  25.0 %
# Current Iteration  6  is at  30.0 %
# Current Iteration  6  is at  35.0 %
# Current Iteration  6  is at  40.0 %
# Current Iteration  6  is at  45.0 %
# Current Iteration  6  is at  50.0 %
# Current Iteration  6  is at  55.0 %
# Current Iteration  6  is at  60.0 %
# Current Iteration  6  is at  65.0 %
# Current Iteration  6  is at  70.0 %
# Current Iteration  6  is at  75.0 %
# Current Iteration  6  is at  80.0 %
# Current Iteration  6  is at  85.0 %
# Current Iteration  6  is at  90.0 %
# Current Iteration  6  is at  95.0 %
# Current Iteration  5  is at  0.0 %
# Current Iteration  5  is at  5.0 %
# Current Iteration  5  is at  10.0 %
# Current Iteration  5  is at  15.0 %
# Current Iteration  5  is at  20.0 %
# Current Iteration  5  is at  25.0 %
# Current Iteration  5  is at  30.0 %
# Current Iteration  5  is at  35.0 %
# Current Iteration  5  is at  40.0 %
# Current Iteration  5  is at  45.0 %
# Current Iteration  5  is at  50.0 %
# Current Iteration  5  is at  55.0 %
# Current Iteration  5  is at  60.0 %
# Current Iteration  5  is at  65.0 %
# Current Iteration  5  is at  70.0 %
# Current Iteration  5  is at  75.0 %
# Current Iteration  5  is at  80.0 %
# Current Iteration  5  is at  85.0 %
# Current Iteration  5  is at  90.0 %
# Current Iteration  5  is at  95.0 %
# Current Iteration  4  is at  0.0 %
# Current Iteration  4  is at  5.0 %
# Current Iteration  4  is at  10.0 %
# Current Iteration  4  is at  15.0 %
# Current Iteration  4  is at  20.0 %
# Current Iteration  4  is at  25.0 %
# Current Iteration  4  is at  30.0 %
# Current Iteration  4  is at  35.0 %
# Current Iteration  4  is at  40.0 %
# Current Iteration  4  is at  45.0 %
# Current Iteration  4  is at  50.0 %
# Current Iteration  4  is at  55.0 %
# Current Iteration  4  is at  60.0 %
# Current Iteration  4  is at  65.0 %
# Current Iteration  4  is at  70.0 %
# Current Iteration  4  is at  75.0 %
# Current Iteration  4  is at  80.0 %
# Current Iteration  4  is at  85.0 %
# Current Iteration  4  is at  90.0 %
# Current Iteration  4  is at  95.0 %
# Current Iteration  3  is at  0.0 %
# Current Iteration  3  is at  5.0 %
# Current Iteration  3  is at  10.0 %
# Current Iteration  3  is at  15.0 %
# Current Iteration  3  is at  20.0 %
# Current Iteration  3  is at  25.0 %
# Current Iteration  3  is at  30.0 %
# Current Iteration  3  is at  35.0 %
# Current Iteration  3  is at  40.0 %
# Current Iteration  3  is at  45.0 %
# Current Iteration  3  is at  50.0 %
# Current Iteration  3  is at  55.0 %
# Current Iteration  3  is at  60.0 %
# Current Iteration  3  is at  65.0 %
# Current Iteration  3  is at  70.0 %
# Current Iteration  3  is at  75.0 %
# Current Iteration  3  is at  80.0 %
# Current Iteration  3  is at  85.0 %
# Current Iteration  3  is at  90.0 %
# Current Iteration  3  is at  95.0 %
# Current Iteration  2  is at  0.0 %
# Current Iteration  2  is at  5.0 %
# Current Iteration  2  is at  10.0 %
# Current Iteration  2  is at  15.0 %
# Current Iteration  2  is at  20.0 %
# Current Iteration  2  is at  25.0 %
# Current Iteration  2  is at  30.0 %
# Current Iteration  2  is at  35.0 %
# Current Iteration  2  is at  40.0 %
# Current Iteration  2  is at  45.0 %
# Current Iteration  2  is at  50.0 %
# Current Iteration  2  is at  55.0 %
# Current Iteration  2  is at  60.0 %
# Current Iteration  2  is at  65.0 %
# Current Iteration  2  is at  70.0 %
# Current Iteration  2  is at  75.0 %
# Current Iteration  2  is at  80.0 %
# Current Iteration  2  is at  85.0 %
# Current Iteration  2  is at  90.0 %
# Current Iteration  2  is at  95.0 %
# Current Iteration  1  is at  0.0 %
# Current Iteration  1  is at  5.0 %
# Current Iteration  1  is at  10.0 %
# Current Iteration  1  is at  15.0 %
# Current Iteration  1  is at  20.0 %
# Current Iteration  1  is at  25.0 %
# Current Iteration  1  is at  30.0 %
# Current Iteration  1  is at  35.0 %
# Current Iteration  1  is at  40.0 %
# Current Iteration  1  is at  45.0 %
# Current Iteration  1  is at  50.0 %
# Current Iteration  1  is at  55.0 %
# Current Iteration  1  is at  60.0 %
# Current Iteration  1  is at  65.0 %
# Current Iteration  1  is at  70.0 %
# Current Iteration  1  is at  75.0 %
# Current Iteration  1  is at  80.0 %
# Current Iteration  1  is at  85.0 %
# Current Iteration  1  is at  90.0 %
# Current Iteration  1  is at  95.0 %
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-32073ae00c81> in <module>()
#     121 points, means = initialize_means(img, clusters)
#     122 means, index = k_means(points, means, clusters)
# --> 123 compress_image(means, index, img)
#
# <ipython-input-1-32073ae00c81> in compress_image(means, index, img)
#     110
#     111         # saving the compressed image.
# --> 112 	misc.imsave('compressed_' + str(clusters) +
#     113 						'_colors.png', recovered)
#     114
#
# AttributeError: module 'scipy.misc' has no attribute 'imsave'
